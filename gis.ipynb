# %%
import pandas as pd
import matplotlib as plt

# %%
df = pd.read_csv('results_java.txt')

# %%
df[(df['s'] == 2) & (df['v'] == 10) & (df['e'] == 10)][['t']].hist(bins=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9de62f7c88>]], dtype=object)

# %%
df[(df['s'] == 2) & (df['v'] == 100) & (df['e'] == 10)][['t']].hist(bins=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9de7e27320>]], dtype=object)

# %%
df[(df['s'] == 2) & (df['v'] == 1000) & (df['e'] == 10)][['t']].hist(bins=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9de6484ef0>]], dtype=object)
